# %% [markdown]
# ## Practical Work 3

# %% [markdown]
# For this practical work, the student will have to develop a Python program that is able to implement the accelerated gradient descent methods <b>(Momentum and NAG)</b> in order to achieve the linear regression of a set of datapoints.

# %% [markdown]
# #### Import numpy, matplotlib.pyplot and make it inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# To have a dataset or set of data points, the student must generate a pair of arrays <b>X</b> and <b>y</b> with the values in <b>X</b> equally distributed between <b>0</b> and <b>20</b> and the values in <b>y</b> such that:
# <b>yi = a*xi + b (and a = -1, b = 2)</b>

# %%
x=np.linspace( 0 ,  20,50) 
x
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %%
y = np.array((-2*x)+1)
y
# Out:
# array([  1.        ,   0.18367347,  -0.63265306,  -1.44897959,
#         -2.26530612,  -3.08163265,  -3.89795918,  -4.71428571,
#         -5.53061224,  -6.34693878,  -7.16326531,  -7.97959184,
#         -8.79591837,  -9.6122449 , -10.42857143, -11.24489796,
#        -12.06122449, -12.87755102, -13.69387755, -14.51020408,
#        -15.32653061, -16.14285714, -16.95918367, -17.7755102 ,
#        -18.59183673, -19.40816327, -20.2244898 , -21.04081633,
#        -21.85714286, -22.67346939, -23.48979592, -24.30612245,
#        -25.12244898, -25.93877551, -26.75510204, -27.57142857,
#        -28.3877551 , -29.20408163, -30.02040816, -30.83673469,
#        -31.65306122, -32.46938776, -33.28571429, -34.10204082,
#        -34.91836735, -35.73469388, -36.55102041, -37.36734694,
#        -38.18367347, -39.        ])

# %% [markdown]
# #### Plot your data points.

# %%
plt.plot(x,y)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# #### Use your final version of the implemented Batch GD algorithm for single variable to find the best line filt of the given data.
# #### Coose the suitable number of iterations, learning rate, and stop criteria.
# #### Calculate r2 score. Shouldn't below 0.9
# #### Plot the required curves (loss-epochs, loss-theta0, loss-theta1, all fitted lines per epoch (single graph) , best fit line)

# %%
max_iteration = 10
tolerance = 0.001 # stop condation when loss function is tolerance 
optm_loss = 0.006
optm_theta0 = 0.7837029042949603
optm_theta1 = -1.9838172727216299
alpha = 0.01
theta0 ,theta1 = 1,1 # intial value 
optm_y = ( -1.9838172727216299*x) + (0.7837029042949603)
plt.plot(x,y,color='red')
plt.plot(x,optm_y,color='yellow')
plt.legend(["original",'optumim'])
plt.show()

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y ,optm_y)
r2
# Out:
# 0.9999131502581577

# %%
list_theta0=[0.7, 0.8070816326530611, 0.7699008621407746, 0.7838414294613638, 0.7796638035633835, 0.7819048981337354, 0.7818693962839144, 0.7826387247465805, 0.783120901232697, 0.7837029042949603]

list_theta1=[-3.040816326530611, -1.6089004581424413, -2.1163957594199694, -1.936607883966333, -2.0003773260598576, -1.9778354713151631, -1.9858802242550517, -1.9830856373358225, -1.9841321207459033, -1.9838172727216299]

epochs=[x for x in range(1,11)]
list_loss =[606.1224489795919, 76.12429519162913, 9.565416314028676, 1.2067129409832489, 0.15697251151211503, 0.02511499413593989, 0.00852826888727131, 0.006417757070901344, 0.0061253547919818, 0.006061416459546271]

# %% [markdown]
# # Plot the required curves (loss-epochs)

# %%
plot_data= pd.DataFrame({'theta0':list_theta0,'theta1':list_theta1,'epoch':epochs,'loss':list_loss})
plot_data
# Out:
#      theta0    theta1  epoch        loss
# 0  0.700000 -3.040816      1  606.122449
# 1  0.807082 -1.608900      2   76.124295
# 2  0.769901 -2.116396      3    9.565416
# 3  0.783841 -1.936608      4    1.206713
# 4  0.779664 -2.000377      5    0.156973
# 5  0.781905 -1.977835      6    0.025115
# 6  0.781869 -1.985880      7    0.008528
# 7  0.782639 -1.983086      8    0.006418
# 8  0.783121 -1.984132      9    0.006125
# 9  0.783703 -1.983817     10    0.006061

# %%
plot_data.plot(x='loss',y=['epoch','theta0','theta1'])
plt.show()

# %%
plot_data.plot(x='loss',y='epoch',color='orange')
plt.scatter(list_loss,epochs)
plt.show()

# %%
plot_data.plot(x='loss',y='theta0',color='red')
plt.scatter(list_loss,list_theta0,color='yellow')
plt.show()

# %%
plot_data.plot(x='loss',y='theta1',color='blue')
plt.scatter(list_loss,list_theta1)
plt.show()

# %% [markdown]
# ### Update your Batch GD for one variable  implementation to be Momentum-Based GD and check your results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### γ takes values between 0 and 1.
# ![image.png](attachment:image.png)

# %%
theta0 ,theta1 = 1,1
vt_0=0
vt_1=0
list_vt0= []
list_vt1= []
h_x = theta0 + (theta1*x) #hyposises
e = h_x -y   # hyposses - real
loss = sum(e**2)/(2*len(y))  # loss function 
tolerance = 0.0001 # stop condation when loss function is tolerance 
list_loss = []
list_theta0 = []
list_theta1= []
max_iteration = 50   # it's i assume
alpha = 0.001
gamma= 0.001
for i in range ( max_iteration):
    h_x = theta0 + (theta1*x) #hyposises
    hypothesis.append(h_x)
    vt_0=(gamma*vt_0)+((alpha/len(y))*sum(h_x -y))
    theta0 = theta0 - vt_0
    vt_1=vt_1 +((alpha/len(y))*sum((h_x -y)*x))
    theta1 = theta1 -vt_1 
    e = h_x -y
    loss = sum(e**2)/(2*len(y))
    list_loss.append(loss)
    list_theta0.append(theta0)
    list_vt0.append(vt_0)
    list_theta1.append(theta1)
    list_vt1.append(vt_1)
    if loss <= tolerance:
        break

# %%
mom = pd.DataFrame({'vt0':list_vt0,'vt1':list_vt1,'loss':list_loss,'theta0':list_theta0,'theta1':list_theta1})
mom
# Out:
#          vt0       vt1        loss    theta0    theta1
# 0   0.030000  0.404082  606.122449  0.970000  0.595918
# 1   0.025959  0.753436  453.058698  0.944041 -0.157518
# 2   0.018395  1.001047  227.595974  0.925646 -1.158565
# 3   0.008358  1.113640   47.059619  0.917288 -2.272205
# 4  -0.002796  1.076149    5.218680  0.920084 -3.348354
# 5  -0.013566  0.893734  123.521355  0.933650 -4.242088
# 6  -0.022501  0.591075  340.040118  0.956151 -4.833163
# 7  -0.028398  0.209027  541.824711  0.984549 -5.042191
# 8  -0.030466 -0.200892  623.760945  1.015015 -4.841299
# 9  -0.028428 -0.583447  543.263902  1.043443 -4.257852
# 10 -0.022564 -0.887132  342.347589  1.066007 -3.370720
# 11 -0.013664 -1.071099  125.633772  1.079670 -2.299621
# 12 -0.002930 -1.110659    5.810379  1.082601 -1.188961
# 13  0.008190 -1.000592   44.973049  1.074411 -0.188370
# 14  0.018199 -0.755832  222.383727  1.056212  0.567462
# 15  0.025749 -0.409448  445.386501  1.030463  0.976911
# ...

# %%
mom.plot(x='loss',y=['vt0','vt1'])
# Out:
# <AxesSubplot:xlabel='loss'>

# %%
mom.plot(x='loss',y=['theta0','theta1'])
# Out:
# <AxesSubplot:xlabel='loss'>

# %% [markdown]
# #### Try another values of momentum term and check your reults.
# #### Try very large values close to one and very small values close to zero.
# #### Try momentum = 0

# %%
theta0 ,theta1 = 1,1
vt_0=0
vt_1=0
list_vt0= []
list_vt1= []
h_x = theta0 + (theta1*x) #hyposises
e = h_x -y   # hyposses - real
loss = sum(e**2)/(2*len(y))  # loss function 
tolerance = 0.0001 # stop condation when loss function is tolerance 
list_loss = []
list_theta0 = []
list_theta1= []
max_iteration = 50   # it's i assume
alpha = 0.001
gamma= 0
for i in range ( max_iteration):
    h_x = theta0 + (theta1*x) #hyposises
    hypothesis.append(h_x)
    vt_0=(gamma*vt_0)+((alpha/len(y))*sum(h_x -y))
    theta0 = theta0 - vt_0
    vt_1=vt_1 +((alpha/len(y))*sum((h_x -y)*x))
    theta1 = theta1 -vt_1 
    e = h_x -y
    loss = sum(e**2)/(2*len(y))
    list_loss.append(loss)
    list_theta0.append(theta0)
    list_vt0.append(vt_0)
    list_theta1.append(theta1)
    list_vt1.append(vt_1)
    if loss <= tolerance:
        break

# %%
mom = pd.DataFrame({'vt0':list_vt0,'vt1':list_vt1,'loss':list_loss,'theta0':list_theta0,'theta1':list_theta1})
mom
# Out:
#          vt0       vt1        loss    theta0    theta1
# 0   0.030000  0.404082  606.122449  0.970000  0.595918
# 1   0.025929  0.753436  453.058698  0.944071 -0.157518
# 2   0.018369  1.001048  227.596525  0.925702 -1.158565
# 3   0.008340  1.113641   47.060052  0.917362 -2.272206
# 4  -0.002805  1.076150    5.218514  0.920167 -3.348356
# 5  -0.013563  0.893736  123.520697  0.933730 -4.242093
# 6  -0.022487  0.591077  340.039665  0.956217 -4.833170
# 7  -0.028375  0.209029  541.825327  0.984593 -5.042199
# 8  -0.030437 -0.200891  623.763062  1.015030 -4.841308
# 9  -0.028398 -0.583447  543.267136  1.043428 -4.257861
# 10 -0.022535 -0.887133  342.350854  1.065963 -3.370728
# 11 -0.013641 -1.071102  125.635878  1.079605 -2.299626
# 12 -0.002917 -1.110664    5.810780  1.082521 -1.188962
# 13  0.008193 -1.000597   44.972292  1.074328 -0.188366
# 14  0.018191 -0.755837  222.383276  1.056138  0.567472
# 15  0.025731 -0.409453  445.387978  1.030407  0.976925
# ...

# %%
mom.plot(x='loss',y=['vt0','vt1'])
plt.show()
mom.plot(x='loss',y=['theta0','theta1'])
plt.show()

# %% [markdown]
# ### Update your Batch GD for one variable  implementation to be NAG and check your results

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
theta0 ,theta1 = 1,1
vt_0=0
vt_1=0
list_vt0= []
list_vt1= []
h_x = theta0 + (theta1*x) #hyposises
e = h_x -y   # hyposses - real
loss = sum(e**2)/(2*len(y))  # loss function 
tolerance = 0.0001 # stop condation when loss function is tolerance 
list_loss = []
list_theta0 = []
list_theta1= []
max_iteration = 50   # it's i assume
alpha = 0.001
gamma= 0
for i in range ( max_iteration):
    h_x = theta0 + (theta1*x) #hyposises
    vt_0=(gamma*vt_0)+((alpha/len(y))*sum(h_x -y))
    theta0 = theta0 - vt_0
    vt_1=vt_1 +((alpha/len(y))*sum((h_x -y)*x))
    theta1 = theta1 -vt_1 
    e = h_x -y
    loss = sum(e**2)/(2*len(y))
    list_loss.append(loss)
    list_theta0.append(theta0)
    list_vt0.append(vt_0)
    list_theta1.append(theta1)
    list_vt1.append(vt_1)
    if loss <= tolerance:
        break

# %%
mom.plot(x='loss',y=['vt0','vt1'])
plt.show()
mom.plot(x='loss',y=['theta0','theta1'])
plt.show()

# %% [markdown]
# ## Congratulations
# ![image.png](attachment:image.png)
